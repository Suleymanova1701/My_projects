# %% [markdown]
# <div class="alert alert-info">
# <h2> Привет ещё раз Анзор! Надеюсь финальный 🤪<a class="tocSkip"> </h2>
#
# Да, я по невнимательности накосячила с расчётами и непраивльно поняла твоё предыдущее замечание — удалила лишний фильтр с дашборда, потому что спешила. Очень тревожат меня сроки((( Надеялась хотя бы начать сборный проект в выходные и не выпасть из когорты 🤓
#
# В целом, довольно легко мне с Tableau. Я хорошо разобралась, мне кажется. С инструментами корректировки дашбордов и презентаций проблем нет, очень жду твоё положительное ревью 😅 Заранее спасибо, лёгкой проверки)
#
#     Дублирую ссылку:
# https://public.tableau.com/app/profile/rozaliya.suleymanova/viz/TED-_17158756027980/TED-?publish=yes

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет!👋</b>
#
# Меня зовут Огурлиев Анзор, я буду ревьюером твоего проекта. Сразу хочу предложить тебе общаться на "ты", если тебе это неудобно, скажи мне об этом. Нам предстоит пройти с тобой через тернистый и от того интересный путь анализа данных! Можешь не переживать, я всегда помогу тебе, если у тебя возникнут вопросы)
#
# По ходу твоей работы я буду оставлять свои комментарии, по выполненным тобой шагам. Попрошу тебя не удалять их, так мне будет проще отслеживать твой прогресс в случае повторной проверки.
#
# Очень важно вести диалог и обсуждать те пункты, которые у тебя могли не получиться, поэтому, ты можешь оставлять свои комментарии, и мы обязательно во всем разберемся! Самое главное - выделяй свои комментарии удобным для тебя способом (цвет, рамка), но так, чтобы они отчетлитво отличались от моих комментариев. Так мы ни в чем не запутаемся)
#
# Свои комментарии я буду выделять так: <font color='green'>зеленый</font>, <font color='gold'>желтый</font> и <font color='red'>красный</font> цвет, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Этот комментарий я буду оставлять, если твое решение оптимально для данного шага.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Это не означает, что ты совершил ошибку. Такими комментариями я буду отмечать места, где ты справился с задачей, но её можно решить ещё лучше. Также в таких комментариях я буду оставлять для тебя другие советы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Если решение, которое ты применил на определенном шаге, требует значительных изменений, то я буду оставлять такой комментарий. Тебе нужно будет подумать еще раз как правильным образом решить данный этап. Если ревью содержит такие комментарии, то я не смогу принять проект с первого раза.
# </div>
#
# P.S. В оглавлении комментария ты увидишь `V1` (`V1`, `V2`, `V3`) - это версия моего комментария, которая понадобится нам с тобой, чтобы не запутаться, если потребуется оставить тебе комментарии после первой проверки.

# %% [markdown]
# Привет!
#
# Здесь моя презентация, легкой провеври, жду обратной связи)
#
# Ссылка на презентацию: https://public.tableau.com/views/TED-_17158756027980/TED-?:language=en-US&publish=yes&:sid=&:display_count=n&:origin=viz_share_link

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Комментарии по дашборду "История выступлений":
#
# 1) Проверь что ты используешь при построении карты. Доли посчитаны некорректно, с 2013 года в Канаде было около 30% выступлений.
#
# 2) На диаграммах у тебя не число выступлений выведено, их не тысячи за год. Также у тебя оси подписаны как число конференций, а вывести нужно число выступлений.
#
# 3) action на карту нужно наложить, чтобы при выборе страны, на других диаграммах остались только выступления, проведенные в выбранной стране.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V2<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Комментарии по дашборду "История выступлений":
#
# 1) Почему на карте ты суммируешь id выступлений, а не считаешь их количество?
#
# 2) На диаграмме также, ты суммируешь id, нужно количество их посчитать.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V3<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Комментарии по дашборду "История выступлений":
#
# Все правильно доработала, молодец!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Комментарии по дашборду "Тематики выступлений":
#
# 1) На круговой диаграмме во всплывающих подсказках число выступлений некорректное выводится. Это не число выступлений.
#
# 2) В таблице нужно посчитать доли тематик в рамках одной страны, другими словами сумма значений в одном столбце должна быть равна 100%.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V2<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Комментарии по дашборду "Тематики выступлений":
#
# 1) Аналогичные ошибки на круговой диаграмме, ты неправильные функции агрегации используешь при расчете, нужно количество выступлений считать, а не суммировать их id.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V3<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Комментарии по дашборду "Тематики выступлений":
#
# Здесь также все верно.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Комментарии по дашборду "Авторы выступлений":
#
# 1) На распределение числа выступлений не должен работать фильтр с топ-N областями.
#
# 2) На диаграмме "Области деятельности" выводится на 1 область меньше, чем в фильтре, нужно поправить, чтобы выводилось столько областей, сколько выбрано в фильтре.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V2<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Комментарии по дашборду "Авторы выступлений":
#
# 1) Фильтр топ-N куда то пропал, его нужно вернуть.
#
# 2) Во всплывающих подсказках на диаграмме "Области деятельности" ты опять суммируешь id выступлений. Лучше выведи число авторов в каждой области.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V3<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Комментарии по дашборду "Авторы выступлений":
#
# Отлично, все правильно доработала!

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Хорошо справилась с последним дашбордом, все правильно описала, можно было бы подобрать другой тип диаграммы, чтобы отразить динамику по годам, например столбчатую накопительную.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Я уверен, что ты приложила все усилия, чтобы сделать этот проект. Это видно по твоей работе, а сформулированные выводы отражают, насколько успешно ты осваиваешь материал.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div class="alert alert-info">
# <h2> Привет Анзор!<a class="tocSkip"> </h2>
#
# Спасибо за обратную связь, я учла твои замечания, поправила некоторые расчёты и настройки. Жду результатов следующей проверки с нетерпением🙏
# Надеюсь успеть ещё выполнить сборный проект, осталась всего неделька 🤪
#
#     Дублирую ссылку:
# https://public.tableau.com/app/profile/rozaliya.suleymanova/viz/TED-_17158756027980/TED-?publish=yes

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Нужно скорректировать все красные комментарии.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Ты отлично справилась с данной работой! Видно, как ты успешно осваиваешь материал, применяешь полученные знания на практике. Мне было очень приятно проверять твою работу, надеюсь, мои комментарии и советы были для тебя полезными.
#
# **Желаю удачи в последующем обучении и исследованиях!**😉
