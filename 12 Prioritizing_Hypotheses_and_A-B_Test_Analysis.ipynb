# %% [markdown]
# <div class="alert alert-info">
# Привет Светлана! Я, наконец-то возвращаюсь с исправленным вариантом проекта 🤪
#
# Спасибо большое за твои комментарии и подсказки. Я постаралась всё учесть и улучшить) Надеюсь, мне это удалось, желаю лёгкой проверки.

# %% [markdown]
# <div class="alert alert-info">
# Привет, Розалия! Меня зовут Светлана Чих и я буду проверять твой проект. Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе. Предлагаю общаться на «ты». Но если это не удобно - дай знать, и мы перейдем на «вы».
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Зелёным цветом отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах.
# </div>
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Жёлтым цветом выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
# </div>
# <div class="alert alert-danger">
# <b>😔 Необходимо исправить:</b> Красным цветом выделены комментарии, без исправления которых, я не смогу принять проект :(
# </div>
# <div class="alert alert-info">
# <b>👂 Совет:</b> Какие-то дополнительные материалы
# </div>
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом.
# Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>🎓 Комментарий студента:</b> Например, вот так.</div>
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#  </div>

# %% [markdown]
# # Приоритезация гипотез и анализ A/B тестов.

# %% [markdown]
# ## Описание проекта (#description_project)
# <a id="description_project"></a>
#
# Аналитик крупного интернет-магазина с отделом маркетинга подготовили список гипотез для увеличения выручки. Необходимо приоритизировать их, запустить A/B тесты и проанализировать результаты.
#
# *Цель исследования:*
# 1. Проанализировать файл с данными о представленных девяти гипотезах по увеличению выручки интернет-магазина с указанными параметрами `Reach`, `Impact`, `Confidence`, `Effort`.
# 2. Применить фреймворк ICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# 3. Применить фреймворк RICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# 4. Указать, как изменилась приоритизация гипотез при применении RICE вместо ICE. Объяснить, почему так произошло.
# 5. Провести A/B-тест и получить результаты, которые описаны в файлах `orders.csv` и `visitors.csv`.
#
# *Ход исследования:*
# 1. Загрузка и оценка качества данных .
# 2. Предобработка и корректировка полученных данных.
# 3. Исследовательский анализ данных по поставленным вопросам.
# 4. Визуализация проведённых исследований.
# 5. Проверка гипотез.
# 6. График кумулятивной выручки по группам. Выводы и предположения.
# 7. График кумулятивного среднего чека по группам. Выводы и предположения.
# 8. График относительного изменения кумулятивного среднего чека группы B к группе A. Выводы и предположения.
# 9. График кумулятивного среднего количества заказов на посетителя по группам. Выводы и предположения.
# 10. График относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Выводы и предположения.
# 11. Точечный график количества заказов по пользователям. Выводы и предположения.
# 12. Расчёт 95-й и 99-й перцентили количества заказов на пользователя. Выбор границы для определения аномальных пользователей.
# 13. Точечный график стоимостей заказов. Выводы и предположения.
# 14. Расчёт 95-й и 99-й перцентили стоимости заказов. Выбор границы для определения аномальных заказов.
# 15. Расчёт статистической значимости различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Выводы и предположения.
# 16. Расчёт статистической значимости различий в среднем чеке заказа между группами по «сырым» данным. Выводы и предположения.
# 17. Расчёт статистической значимости различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Выводы и предположения.
# 18. Расчёт статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным. Выводы и предположения.
# 19. Принятие решения по результатам теста и его объяснение. Варианты решений:
#     - Остановить тест, зафиксировать победу одной из групп.
#     -  Остановить тест, зафиксировать отсутствие различий между группами.
#     -  Продолжить тест.
#
#
# ## Описание данных (#description_data)
#
# В основных данных есть информация о заказах и посещениях сайта. Информация представлена в трёх датасетах. Файлы `hypothesis.csv`,  `orders.csv` и `visitors.csv`.
#
# Структура представленных файлов:
#
#
# - Гипотезы — `hypothesis.csv`:
#     - Hypothesis — краткое описание гипотезы;
#     - Reach — охват пользователей по 10-балльной шкале;
#     - Impact — влияние на пользователей по 10-балльной шкале;
#     - Confidence — уверенность в гипотезе по 10-балльной шкале;
#     - Efforts — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение `Efforts`, тем дороже проверка гипотезы.
# - Заказы — `orders.csv`:
#     - transactionId — идентификатор заказа;
#     - visitorId — идентификатор пользователя, совершившего заказ;
#     - date — дата, когда был совершён заказ;
#     - revenue — выручка заказа;
#     - group — группа A/B-теста, в которую попал заказ.
# - Визиты — `visitors.csv`:
#     - date — дата;
#     - group — группа A/B-теста;
#     - visitors — количество пользователей в указанную дату в указанной группе A/B-теста.

# %% [markdown]
# ## Настройка параметров анализа
# ### Импорт библиотек и настройка параметров (#settings)
# <a id="settings"></a>

# %%
# Импортирую все необходимые библиотеки
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import datetime as dt
from matplotlib import pyplot as plt
from scipy import stats as st
from plotly import graph_objects as go
import plotly.express as px

pd.set_option("max_colwidth", 120)
pd.set_option("display.width", 500)

import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

plt.rcParams["figure.figsize"] = (20, 5)

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Импорты размещаются в начале работе, если в процессе выполнения работы нужны будут дополнительные бибилиотеки, то их тоже нужно будет добавлять в эту ячейку
# </div>

# %% [markdown]
# ### Функции (#functions)
# <a id="functions"></a>
#
# #### Функции для предобработки данных

# %%
def get_count_and_share(df: pd.DataFrame, groupby: str = "city") -> pd.DataFrame:
    """
    Функция формирует и выводит сводную таблицу по одному из атрибутов (город по умолчанию),
    в которой отражает количество и долю строк каждого из этих атрибутов.
    """
    # считаю количество пользователей
    count_and_share = df.groupby(groupby).agg({groupby: "count"})

    # переименовываю столбец
    count_and_share.columns = ["count"]

    # считаю долю
    count_and_share["%_share_of_"] = round(
        (count_and_share["count"]).div(df["transactionId"].count(), axis=0), 4
    )

    count_and_share = count_and_share[count_and_share["%_share_of_"] >= 0.001]

    # переименовываю столбцы финального датафрейма
    count_and_share.columns = ["count_of_" + groupby, "%_share_of_" + groupby]

    # сортирую финальный датафрейм по убыванию
    count_and_share = count_and_share.sort_values(
        by="%_share_of_" + groupby, ascending=False
    )

    count_and_share = count_and_share.style.format(
        {"%_share_of_" + groupby: "{:.2%}".format}
    ).background_gradient(cmap="Greens")
    return count_and_share

# %% [markdown]
# #### Функции для анализа и визуализации данных.

# %%
def get_cumulative_group_revenue(orders: pd.DataFrame, visitors: pd.DataFrame):
    """
    Функция строит график кумулятивной выручки по группам пользователей
    """

    #
    datesGroups = orders[["date", "group"]].drop_duplicates()
    # получаем агрегированные кумулятивные по дням данные о заказах
    ordersAggregated = datesGroups.apply(
        lambda x: orders[
            np.logical_and(orders["date"] <= x["date"], orders["group"] == x["group"])
        ].agg(
            {
                "date": "max",
                "group": "max",
                "transactionId": "nunique",
                "visitorId": "nunique",
                "revenue": "sum",
            }
        ),
        axis=1,
    ).sort_values(by=["date", "group"])

    # получаем агрегированные кумулятивные по дням данные о посетителях интернет-магазина
    visitorsAggregated = datesGroups.apply(
        lambda x: visitors[
            np.logical_and(
                visitors["date"] <= x["date"], visitors["group"] == x["group"]
            )
        ].agg(
            {
                "date": "max",
                "group": "max",
                "visitors": "sum",
            }
        ),
        axis=1,
    ).sort_values(by=["date", "group"])

    # объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
    cumulativeData = ordersAggregated.merge(
        visitorsAggregated, left_on=["date", "group"], right_on=["date", "group"]
    )
    cumulativeData.columns = [
        "date",
        "group",
        "orders",
        "buyers",
        "revenue",
        "visitors",
    ]

    # датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
    cumulativeRevenueA = cumulativeData[cumulativeData["group"] == "A"][
        ["date", "revenue", "orders"]
    ]

    # датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
    cumulativeRevenueB = cumulativeData[cumulativeData["group"] == "B"][
        ["date", "revenue", "orders"]
    ]

    return cumulativeData, cumulativeRevenueA, cumulativeRevenueB

# %%
def display_cumulative_group_revenue(
    cumulative_revenueA: pd.DataFrame, cumulative_revenueB: pd.DataFrame
):
    """
    Функция выводит график кумулятивной выручки
    на основании данных функции get_cumulative_group_revenue
    """

    # Строим график выручки группы А
    plt.plot(cumulative_revenueA["date"], cumulative_revenueA["revenue"], label="A")

    # Строим график выручки группы B
    plt.plot(cumulative_revenueB["date"], cumulative_revenueB["revenue"], label="B")
    plt.legend()
    plt.xlabel("Выручка покупателей по группам, руб")
    plt.title("Динамика выручки по группам покупателей  ")
    plt.show()

# %%
def display_cumulative_avg_check(
    cumulativeRevenueA: pd.DataFrame, cumulativeRevenueB: pd.DataFrame
):
    """



    Функция возвращает датафреймы с кумулятивными средними чеками



    с разбивкой по группам на основании данных функции get_cumulative_group_revenue
    """

    plt.plot(
        cumulativeRevenueA["date"],
        cumulativeRevenueA["revenue"] / cumulativeRevenueA["orders"],
        label="A",
    )
    plt.plot(
        cumulativeRevenueB["date"],
        cumulativeRevenueB["revenue"] / cumulativeRevenueB["orders"],
        label="B",
    )
    plt.legend()
    plt.xlabel("Изменение кумулятивного среднего чека, руб")
    plt.title("Динамика кумулятивного среднего чека по группам.")
    plt.show()

# %%
def display_merged_Cumulative_Revenue(
    cumulativeRevenueA: pd.DataFrame, cumulativeRevenueB: pd.DataFrame
):
    """
    Функция возвращает график кумулятивной выручки
    """
    # собираем данные в одном датафрейме
    mergedCumulativeRevenue = cumulativeRevenueA.merge(
        cumulativeRevenueB,
        left_on="date",
        right_on="date",
        how="left",
        suffixes=["A", "B"],
    )
    # cтроим отношение средних чеков
    plt.plot(
        mergedCumulativeRevenue["date"],
        (mergedCumulativeRevenue["revenueB"] / mergedCumulativeRevenue["ordersB"])
        / (mergedCumulativeRevenue["revenueA"] / mergedCumulativeRevenue["ordersA"])
        - 1,
    )

    # добавляем ось X
    plt.axhline(y=0, color="black", linestyle="--")
    plt.legend()
    plt.xlabel("Отношения кумулятивного среднего чека групп А и B")
    plt.title("Динамика отношения кумулятивного среднего чека групп А и B")
    plt.show()

# %% [markdown]
# ## Знакомство с данными (#data)
# <a id="data"></a>

# %%
try:
    hypothesis, orders, visitors = (
        pd.read_csv(
            # гипотезы
            "/datasets/hypothesis.csv"
        ),
        pd.read_csv(
            # заказы
            "/datasets/orders.csv"
        ),
        pd.read_csv(
            # посещения
            "/datasets/visitors.csv"
        ),
    )
except:
    hypothesis, orders, visitors = (
        pd.read_csv(
            # гипотезы
            "hypothesis.csv"
        ),
        pd.read_csv(
            # заказы
            "orders.csv"
        ),
        pd.read_csv(
            # посещения
            "visitors.csv"
        ),
    )
hypothesis
# Out:
#                                                                                                      Hypothesis  Reach  Impact  Confidence  Efforts
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей      3      10           8        6
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов      2       5           4       10
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа      8       3           7        3
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар      8       3           3        8
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей      3       1           1        1
# ...

# %%
hypothesis.columns = ["hypothesis", "reach", "impact", "confidence", "efforts"]
hypothesis
# Out:
#                                                                                                      hypothesis  reach  impact  confidence  efforts
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей      3      10           8        6
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов      2       5           4       10
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа      8       3           7        3
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар      8       3           3        8
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей      3       1           1        1
# ...

# %%
orders
# Out:
#       transactionId   visitorId        date  revenue group
# 0        3667963787  3312258926  2019-08-15     1650     B
# 1        2804400009  3642806036  2019-08-15      730     B
# 2        2961555356  4069496402  2019-08-15      400     A
# 3        3797467345  1196621759  2019-08-15     9759     B
# 4        2282983706  2322279887  2019-08-15     2308     B
# ...             ...         ...         ...      ...   ...
# 1192     2662137336  3733762160  2019-08-14     6490     B
# 1193     2203539145   370388673  2019-08-14     3190     A
# 1194     1807773912   573423106  2019-08-14    10550     A
# 1195     1947021204  1614305549  2019-08-14      100     A
# 1196     3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB

# %%
visitors
# Out:
#           date group  visitors
# 0   2019-08-01     A       719
# 1   2019-08-02     A       619
# 2   2019-08-03     A       507
# 3   2019-08-04     A       717
# 4   2019-08-05     A       756
# ..         ...   ...       ...
# 57  2019-08-27     B       720
# 58  2019-08-28     B       654
# 59  2019-08-29     B       531
# 60  2019-08-30     B       490
# 61  2019-08-31     B       718
#
# [62 rows x 3 columns]

# %%
visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %% [markdown]
# Предпросмотр данных показывает, что датасет посещений `visitors` детализирует информацию о заказах датасета `orders`.
# Датасет `hypothesis` содержит информацию о гипотезах с оценкой по 10-бальной шкале: охвате пользователей, влиянии на пользователей, уверенности в гипотезе и затратах ресурсов на проверку гипотезы.
#
# Приступаю к предобработке данных.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Датасеты загружены, проведено первичное знакомство с данными
# </div>

# %% [markdown]
# ## Предобработка данных (#data_preprocessing)
# <a id="data"></a>

# %%
# преобразование типа данных в столбце с датой
visitors["date"] = visitors["date"].map(lambda x: dt.datetime.strptime(x, "%Y-%m-%d"))
visitors["date"].unique()
# Out:
# array(['2019-08-01T00:00:00.000000000', '2019-08-02T00:00:00.000000000',
#        '2019-08-03T00:00:00.000000000', '2019-08-04T00:00:00.000000000',
#        '2019-08-05T00:00:00.000000000', '2019-08-06T00:00:00.000000000',
#        '2019-08-07T00:00:00.000000000', '2019-08-08T00:00:00.000000000',
#        '2019-08-09T00:00:00.000000000', '2019-08-10T00:00:00.000000000',
#        '2019-08-11T00:00:00.000000000', '2019-08-12T00:00:00.000000000',
#        '2019-08-13T00:00:00.000000000', '2019-08-14T00:00:00.000000000',
#        '2019-08-15T00:00:00.000000000', '2019-08-16T00:00:00.000000000',
#        '2019-08-17T00:00:00.000000000', '2019-08-18T00:00:00.000000000',
#        '2019-08-19T00:00:00.000000000', '2019-08-20T00:00:00.000000000',
#        '2019-08-21T00:00:00.000000000', '2019-08-22T00:00:00.000000000',
#        '2019-08-23T00:00:00.000000000', '2019-08-24T00:00:00.000000000',
#        '2019-08-25T00:00:00.000000000', '2019-08-26T00:00:00.000000000',
# ...

# %% [markdown]
# <div class="alert alert-info"> Проверка датафрейма `visitors` отражает диапазон распределения дат посещения сайта с 1 по 31 августа 2019 года.

# %%
# преобразование типа данных в столбце с датой
orders["date"] = orders["date"].map(lambda x: dt.datetime.strptime(x, "%Y-%m-%d"))

# %%
orders["transactionId"].duplicated().count()
# Out:
# 1197

# %%
orders["date"].unique()
# Out:
# array(['2019-08-15T00:00:00.000000000', '2019-08-16T00:00:00.000000000',
#        '2019-08-01T00:00:00.000000000', '2019-08-22T00:00:00.000000000',
#        '2019-08-17T00:00:00.000000000', '2019-08-23T00:00:00.000000000',
#        '2019-08-02T00:00:00.000000000', '2019-08-18T00:00:00.000000000',
#        '2019-08-24T00:00:00.000000000', '2019-08-03T00:00:00.000000000',
#        '2019-08-25T00:00:00.000000000', '2019-08-28T00:00:00.000000000',
#        '2019-08-19T00:00:00.000000000', '2019-08-06T00:00:00.000000000',
#        '2019-08-26T00:00:00.000000000', '2019-08-29T00:00:00.000000000',
#        '2019-08-04T00:00:00.000000000', '2019-08-20T00:00:00.000000000',
#        '2019-08-09T00:00:00.000000000', '2019-08-07T00:00:00.000000000',
#        '2019-08-30T00:00:00.000000000', '2019-08-05T00:00:00.000000000',
#        '2019-08-27T00:00:00.000000000', '2019-08-21T00:00:00.000000000',
#        '2019-08-08T00:00:00.000000000', '2019-08-10T00:00:00.000000000',
# ...

# %% [markdown]
# <div class="alert alert-info"> Проверка датафрейма `orders` отражает диапазон распределения дат оформления заказов с 1 по 31 августа 2019 года.

# %%
# Проверяю распределение пользователей по группам с помощью функции 'get_count_and_share()'
get_count_and_share(orders, "group")
# Out:
# <style  type="text/css" >
# #T_34459_row0_col0,#T_34459_row0_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_34459_row1_col0,#T_34459_row1_col1{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_34459_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count_of_group</th>        <th class="col_heading level0 col1" >%_share_of_group</th>    </tr>    <tr>        <th class="index_name level0" >group</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_34459_level0_row0" class="row_heading level0 row0" >B</th>
#                         <td id="T_34459_row0_col0" class="data row0 col0" >640</td>
#                         <td id="T_34459_row0_col1" class="data row0 col1" >53.47%</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# <div class="alert alert-info">Таблица распределения заказов пользователей по группам полученная из датафрейма `orders` отражает доли заказов по группам — пользователей группы `B` больше, чем пользователей группы `A`

# %%
# Проверяю распределение заказов пользователей по датам с помощью функции 'get_count_and_share()'
get_count_and_share(orders, "date")
# Out:
# <style  type="text/css" >
# #T_81b47_row0_col0,#T_81b47_row0_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_81b47_row1_col0,#T_81b47_row1_col1,#T_81b47_row2_col0,#T_81b47_row2_col1{
#             background-color:  #005120;
#             color:  #f1f1f1;
#         }#T_81b47_row3_col0,#T_81b47_row3_col1,#T_81b47_row4_col0,#T_81b47_row4_col1{
#             background-color:  #005f26;
#             color:  #f1f1f1;
#         }#T_81b47_row5_col0,#T_81b47_row5_col1,#T_81b47_row6_col0,#T_81b47_row6_col1{
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }#T_81b47_row7_col0,#T_81b47_row7_col1,#T_81b47_row8_col0,#T_81b47_row8_col1{
#             background-color:  #0b7734;
#             color:  #f1f1f1;
#         }#T_81b47_row9_col0,#T_81b47_row9_col1,#T_81b47_row10_col0,#T_81b47_row10_col1{
#             background-color:  #17813d;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# <div class="alert alert-danger">
#     <s><b>😔 Необходимо исправить:</b> Что дала такая проверка? Здесь должны быть какие-то выводы</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"><b>Добавила вывод</b>
# Таблица распределения заказов пользователей по датам, полученная из датафрейма `orders` отражает диапазоны дат оформления заказов, количества и долей заказов в течение всего месяца. В дальнейшем следует обратить внимание на наличие скачков на графике выручки и количества заказов в эти даты.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# ## Приоритизация гипотез (#Prioritization_of_hypotheses)

# %%
#  расчёт ICE для гипотез. добавление полученных значений ICE к датафрейму hypothesis
hypothesis["ICE"] = (
    hypothesis["impact"] * hypothesis["confidence"] / hypothesis["efforts"]
)

hypothesis.sort_values(by="ICE", ascending=False)
# Out:
#                                                                                                      hypothesis  reach  impact  confidence  efforts        ICE
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения      1       9           9        5  16.200000
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей      3      10           8        6  13.333333
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок     10       7           8        5  11.200000
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию      5       3           8        3   8.000000
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа      8       3           7        3   7.000000
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Для того, что бы полностью выводить гипотезы рекомендую использовать настройку pd.options.display.max_colwidth = 100, где 100 - количество символов. Кстати, pandas имеет много настроек - https://pandas.pydata.org/docs/user_guide/options.html. В сети есть публикации по этому поводу, например, https://towardsdatascience.com/8-commonly-used-pandas-display-options-you-should-know-a832365efa95. Лучше все же использовать дополнительные настройки тогда, когда в этом есть прямая необходимость, как в нашем проекте.
# </div>

# %% [markdown]
# <div class="alert alert-info">  Большое спасибо за рекомендацию, исправила ширину датафреймов в начале проекта 🤝 🙃

# %% [markdown]
# <div class="alert alert-info">
# По методу `ICE`  (от англ. impact, confidence, effort / ease «влияние, уверенность, усилия / простота») наиболее приоритетными гипотезами стали:
#
# 9-ая — `Запустить акцию, дающую скидку на товар в день рождения`,
# 1-ая — `Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей`,
# 8-ая — `Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок`.
# </div>
#
# Их значение `ICE` выше 10.

# %%
#  расчёт RICE для гипотез. добавление полученных значений RICE к датафрейму hypothesis
hypothesis["RICE"] = (
    hypothesis["reach"]
    * hypothesis["impact"]
    * hypothesis["confidence"]
    / hypothesis["efforts"]
)
hypothesis.sort_values(by="RICE", ascending=False)
# Out:
#                                                                                                      hypothesis  reach  impact  confidence  efforts        ICE   RICE
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок     10       7           8        5  11.200000  112.0
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа      8       3           7        3   7.000000   56.0
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей      3      10           8        6  13.333333   40.0
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию      5       3           8        3   8.000000   40.0
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Нужно дать полную формулировку гипотез, у тебя указаны лишь индексы. Индексы могут поменяться, или у заказчика может список гипотез быть в другом порядке. И что значит параметр Reach?</s>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# При расчёте `RICE` изменились лидеры в гонке приоритетных гипотез, теперь самой приоритетной становятся :
#
# 8-ая — `Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок`,
# 3-я — `Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа`,
# 1-ая — `Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей`.
#
# Это изменение произошло за счёт высокого параметра `Reach` (показатель количества пользователей, которых затронет изменение) у новых лидеров.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Отлично получилось, молодец!
# </div>

# %% [markdown]
# ## Анализ A/B-теста (#A/B_test_analysis)
#
# ### График кумулятивной выручки по группам.

# %%
# рассчитываю кумулятивную выручку по группам
cumulativeData, cumulativeRevenueA, cumulativeRevenueB = get_cumulative_group_revenue(
    orders, visitors
)

# %%
# строю сравнительный график кумулятивной выручки
display_cumulative_group_revenue(cumulativeRevenueA, cumulativeRevenueB)

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Все графики долдны быть оформлены, у них должны быть заголовки и подписи осей, это нужно исправить по всей работе</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> График исправлен)

# %% [markdown]
# После 13 августа сегмент `'B'` вырвался вперёд и продолжал лидировать весь остаток теста.
# Также значительный рывки роста отмечены примерно в период с 18 по 20 августа.
# Это может свидетельствовать о влиянии аномально больших заказов на конечные результаты. При заключительном анализе их нужно удалить.
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>
#
# ### График кумулятивного среднего чека по группам.

# %%
#  строю сравнительный график кумулятивной среднего чека
display_cumulative_avg_check(cumulativeRevenueA, cumulativeRevenueB)

# %% [markdown]
# Кумулятивное значение среднего чека по сегментам колеблется.
# Принимать решение по этой метрике рано, требуется дополнительный анализ выбросов, которые так сильно влияют на результаты.
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>
#
#
# ### График относительного изменения кумулятивного среднего чека группы B к группе A.

# %%
# график отношения кумулятивного среднего чека групп А и В
display_merged_Cumulative_Revenue(cumulativeRevenueA, cumulativeRevenueB)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# График относительного различия в среднем чеке между группами отражает несколько скачков 6 августа, 19 августа и падений — 5августа и 13 августа.
# Результаты теста значительно и резко менялись в эти и другие даты. Это может указывать на аномальные заказы.
#
# Аналогично проанализируем график кумулятивного среднего количества заказов на посетителя по группам.
# Передадим ему минимальное и максимальное значения оси x; минимальное и максимальное значения оси y — ["2019-08-01", '2019-09-01', 0, 0.05].
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>
#
# ### График кумулятивного среднего количества заказов на посетителя по группам.

# %%
# считаем среднее количество заказов на посетителя
cumulativeData["conversion"] = cumulativeData["orders"] / cumulativeData["visitors"]

# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData["group"] == "A"]

# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData["group"] == "B"]

# строим графики
plt.plot(cumulativeDataA["date"], cumulativeDataA["conversion"], label="A")
plt.plot(cumulativeDataB["date"], cumulativeDataB["conversion"], label="B")
plt.legend()
plt.xlabel("Конверсия покупателей по группам")
plt.title("Динамика конверсии по группам покупателей  ")

# задаем масштаб осей
plt.axis([dt.datetime(2019, 8, 1), dt.datetime(2019, 9, 1), 0, 0.05])
plt.show()

# %% [markdown]
# До 6 августа график демонстрирует колебания по кумулятивному среднему количеству заказов в обеих группах, но постепенно сегмент `'B'` выровнялся и зафиксировался примерно около одного значения, больше значения сегмента A.
# На изменённом масштабе графика видно, что абсолютное значение колебания в начале и в конце теста не слишком большое: от 3% до 4%. В относительных величинах — это почти в 2 раза. Потому, если убрать масштаб осей, будет казаться, что колебания продолжаются, и среднее количество заказов по группам не установилось около своего среднего значения.
#
# Построю график изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>
#
# ### График относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.

# %%
# объединяю датафреймы
mergedCumulativeConversions = cumulativeDataA[["date", "conversion"]].merge(
    cumulativeDataB[["date", "conversion"]],
    left_on="date",
    right_on="date",
    how="left",
    suffixes=["A", "B"],
)

plt.plot(
    mergedCumulativeConversions["date"],
    mergedCumulativeConversions["conversionB"]
    / mergedCumulativeConversions["conversionA"]
    - 1,
    label="Относительный прирост кумулятивного среднего количества заказов на посетителя группы B относительно группы A",
)
plt.legend()

plt.axhline(y=0, color="black", linestyle="--")
plt.axhline(y=0.2, color="grey", linestyle="--")

plt.xlabel(
    "Прирост кумулятивного среднего количнества заказов на посетителя группы B относительно группы A"
)
plt.title(
    "Динамика относительного прироста кумулятивного среднего количнества заказов на посетителя группы B относительно группы A"
)
plt.axis([dt.datetime(2019, 8, 1), dt.datetime(2019, 9, 1), -0.2, 0.3])
plt.show()

# %% [markdown]
# До 6 августа группа  `'B'` проигрывала группе `'A'`, затем вырвалась вперёд.
# График относительного различия метрики между группами демонстрирует лидерство группы `'B'` после этой даты.
# А к 15 августа эта группа достигла прироста в 20% относительно группы `'A'`.
# В целом отношение среднего количества заказов на посетителя ещё не установилось, и сейчас делать какие-либо выводы по тесту нельзя.
# Впрочем, сперва стоит проанализировать аномалии, возможно, они изменят картину. Сделаем это в следующем уроке.
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>
#
# ### Точечный график количества заказов по пользователям.
#
# Если дорогой заказ попадёт в одну из групп теста, он сразу же исказит результаты и сделает победителем ту группу, где оказался. При этом такие покупки — редкость, исключение, которое проявилось не из-за тестирования гипотезы, а случайно.
#
# Помимо среднего чека, анализируют и конверсию. Напомним, что она равна отношению числа заказов к количеству посетителей сайта за время теста.
# Пользователи, совершившие много заказов, влияют на числитель формулы конверсии. Скорее всего, их поведение отличается от нормального. Если речь не идёт об интернет-магазине с регулярным спросом, «обычный» пользователь совершает не больше двух заказов за короткий срок.
#
# Подсчитаем количество заказов по пользователям и посмотрим на результат.

# %%
ordersByUsers = orders.groupby("visitorId", as_index=False).agg(
    {"transactionId": "nunique"}
)

ordersByUsers.columns = ["userId", "orders"]

# серия из чисел от 0 до количества наблюдений в ordersByUsers
x_values = pd.Series(range(0, len(ordersByUsers)))

plt.scatter(x_values, ordersByUsers["orders"])
plt.axis([-10, 1100, -0.2, 12])
plt.title("График количества заказов покупателей")
plt.xlabel("Количество заказов покупателей")
plt.show()

# %% [markdown]
# Пользователей, заказавших более двух раз, совсем мало. С большой вероятностью они могут быть аномальными. Для проверки аномального количества заказов рассчитаю 95-ый и 99-ый перцентили.
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>
#
# ### Расчёт 95-й и 99-й перцентили количества заказов на пользователя. Выбор границы для определения аномальных пользователей.

# %%
print(ordersByUsers.sort_values(by="orders", ascending=False).head(10))

# Метод np.percentile('column', [percentile1, percentile2, percentile3]) находит перцентили.
np.percentile(ordersByUsers["orders"], [95, 99])
# Out:
#           userId  orders
# 1023  4256040402      11
# 591   2458001652      11
# 569   2378935119       9
# 487   2038680547       8
# 44     199603092       5
# 744   3062433592       5
# 55     237748145       5
# 917   3803269165       5
# 299   1230306981       5
# 897   3717692402       5
# array([2., 4.])

# %% [markdown]
# Не более 5% пользователей совершали больше двух заказов. И не более 1% пользователей — больше четырёх заказов.
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>
#
# ### Точечный график стоимостей заказов.

# %%
# строю график выручки заказов покупателей
revenueByUsers = orders.groupby("visitorId", as_index=False).agg({"revenue": "sum"})

revenueByUsers.columns = ["userId", "revenue"]

# серия из чисел от 0 до количества наблюдений в ordersByUsers
x_values = pd.Series(range(0, len(revenueByUsers["revenue"])))

plt.scatter(x_values, revenueByUsers["revenue"])
plt.axis([-10, 1100, -0.2, 120000])
plt.title("График выручки заказов покупателей")
plt.xlabel("Суммы заказов покупателей")
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Здесь нужно построить такой же график, как и по количеству заказов, сначала по полным данным, затем без выбросов, что бы хорошо рассмотреть основную массу заказов</s>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Исправленный график выше</b>
#
# Вывод: Большая часть заказов в пределах нескольких десятков тысяч рублей. Для более конкретных выводов найду выборочные перцентили и выберу границы для определения аномальных заказов по аналогии с поиском аномалий по количеству заказов.
# </div>
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Отлично получилось!
# </div>
#
# ### Расчёт 95-й и 99-й перцентили стоимости заказов. Выбор границы для определения аномальных заказов.

# %%
# Вывожу первые 10 строк таблицы и определяю перцентили
print(revenueByUsers.head(10))
print(np.percentile(revenueByUsers["revenue"], [95, 99]))
# Out:
#      userId  revenue
# 0   5114589      570
# 1   6958315     1490
# 2   8300375    12300
# 3  11685486     6201
# 4  39475350     3990
# 5  47206413      730
# 6  48147722     1090
# 7  54447517      130
# 8  56960363     1490
# 9  66685450     7990
# [32899.5 67750. ]

# %% [markdown]
# Вывод: в выборке присутствуют аномально большие стоимости заказов, судя по выводу первых строк таблицы.
# 95-ый и 99-ый перцентили стоимости заказов показывают, что не более, чем у 5% заказов чек дороже 28 000 рублей. И не больше, чем у 1% заказов — дороже 58 233,2 рублей.
#
# Далее посчитаю статистическую значимость различий в среднем числе заказов на пользователя и среднем чеке между группами по «сырым» данным — без удаления аномальных пользователей.
# Сформулирую гипотезы.
# H0: различий в среднем количестве заказов между группами нет.
# H1: различия в среднем количестве заказов между группами есть.
#
# ### Расчёт статистической значимости различий в среднем количестве заказов на посетителя между группами по «сырым» данным.

# %%
visitorsADaily = visitors[visitors["group"] == "A"][["date", "visitors"]]
visitorsADaily.columns = ["date", "visitorsPerDateA"]

visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily["date"] <= x["date"]].agg(
        {"date": "max", "visitorsPerDateA": "sum"}
    ),
    axis=1,
)
visitorsACummulative.columns = ["date", "visitorsCummulativeA"]

visitorsBDaily = visitors[visitors["group"] == "B"][["date", "visitors"]]
visitorsBDaily.columns = ["date", "visitorsPerDateB"]

visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily["date"] <= x["date"]].agg(
        {"date": "max", "visitorsPerDateB": "sum"}
    ),
    axis=1,
)
visitorsBCummulative.columns = ["date", "visitorsCummulativeB"]

ordersADaily = (
    orders[orders["group"] == "A"][["date", "transactionId", "visitorId", "revenue"]]
    .groupby("date", as_index=False)
    .agg({"transactionId": pd.Series.nunique, "revenue": "sum"})
)
ordersADaily.columns = ["date", "ordersPerDateA", "revenuePerDateA"]

ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily["date"] <= x["date"]].agg(
        {"date": "max", "ordersPerDateA": "sum", "revenuePerDateA": "sum"}
    ),
    axis=1,
).sort_values(by=["date"])
ordersACummulative.columns = [
    "date",
    "ordersCummulativeA",
    "revenueCummulativeA",
]

ordersBDaily = (
    orders[orders["group"] == "B"][["date", "transactionId", "visitorId", "revenue"]]
    .groupby("date", as_index=False)
    .agg({"transactionId": pd.Series.nunique, "revenue": "sum"})
)
ordersBDaily.columns = ["date", "ordersPerDateB", "revenuePerDateB"]

ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily["date"] <= x["date"]].agg(
        {"date": "max", "ordersPerDateB": "sum", "revenuePerDateB": "sum"}
    ),
    axis=1,
).sort_values(by=["date"])
ordersBCummulative.columns = [
    "date",
    "ordersCummulativeB",
    "revenueCummulativeB",
]

data = (
    ordersADaily.merge(ordersBDaily, left_on="date", right_on="date", how="left")
    .merge(ordersACummulative, left_on="date", right_on="date", how="left")
    .merge(ordersBCummulative, left_on="date", right_on="date", how="left")
    .merge(visitorsADaily, left_on="date", right_on="date", how="left")
    .merge(visitorsBDaily, left_on="date", right_on="date", how="left")
    .merge(visitorsACummulative, left_on="date", right_on="date", how="left")
    .merge(visitorsBCummulative, left_on="date", right_on="date", how="left")
)

ordersByUsersA = (
    orders[orders["group"] == "A"]
    .groupby("visitorId", as_index=False)
    .agg({"transactionId": pd.Series.nunique})
)
ordersByUsersA.columns = ["visitorId", "orders"]

ordersByUsersB = (
    orders[orders["group"] == "B"]
    .groupby("visitorId", as_index=False)
    .agg({"transactionId": pd.Series.nunique})
)
ordersByUsersB.columns = ["visitorId", "orders"]

sampleA = pd.concat(
    [
        ordersByUsersA["orders"],
        pd.Series(
            0,
            index=np.arange(
                data["visitorsPerDateA"].sum() - len(ordersByUsersA["orders"])
            ),
            name="orders",
        ),
    ],
    axis=0,
)

sampleB = pd.concat(
    [
        ordersByUsersB["orders"],
        pd.Series(
            0,
            index=np.arange(
                data["visitorsPerDateB"].sum() - len(ordersByUsersB["orders"])
            ),
            name="orders",
        ),
    ],
    axis=0,
)

print("{0:.5f}".format(st.mannwhitneyu(sampleA, sampleB)[1]))

print("{0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# 0.01679
# 0.138

# %% [markdown]
# Вывод: По «сырым» данным различия в среднем числе заказов групп A и B есть.
#
# P-value меньше 0.05, потому нулевую гипотезу отвергаем. Анализ «сырых данных» сообщает, что в среднем количестве заказов между группами есть статистически значимые различия. Относительный прирост среднего группы B к конверсии группы A равен 13,8%.
# Осталось сравнить средние чеки по «сырым данным», а затем обе метрики ещё раз после удаления выбросов.
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>
#
# Сформулирую гипотезы.
# H0: различий в среднем чеке между группами нет.
# H1: различия в среднем чеке между группами есть.
#
# ### Расчёт статистической значимости различий в среднем чеке заказа между группами по «сырым» данным.

# %%
print(
    "{0:.3f}".format(
        st.mannwhitneyu(
            orders[orders["group"] == "A"]["revenue"],
            orders[orders["group"] == "B"]["revenue"],
        )[1]
    )
)
print(
    "{0:.3f}".format(
        orders[orders["group"] == "B"]["revenue"].mean()
        / orders[orders["group"] == "A"]["revenue"].mean()
        - 1
    )
)
# Out:
# 0.729
# 0.259

# %% [markdown]
# P-value значительно больше 0.05. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет. Впрочем, средний чек группы B значительно выше среднего чека группы A — на 25,9%
#
# Найденные 95-й и 99-й перцентили средних чеков равны 28 000 и  58 233,2 рублям соответственно. А 95-й и 99-й перцентили количества заказов на одного пользователя равны 2 и 4 заказа на пользователя.
#
# Принимаю за аномальных пользователей тех, кто совершил от 3 заказов или совершил заказ дороже 30 000 рублей. Так я уберу 5% пользователей с наибольшим числом заказов и от 1% до 5% пользователей с дорогими заказами. Сделаю срезы пользователей с числом заказов больше 2 — `usersWithManyOrders` и пользователей, совершивших заказы дороже 30 000 — `usersWithExpensiveOrders`. Объединим их в таблице `abnormalUsers`.
#
# Узнаю, сколько всего аномальных пользователей атрибутом `shape`.
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>
#
# ## Расчёт статистической значимости различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.

# %%
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA["orders"] > 2]["visitorId"],
        ordersByUsersB[ordersByUsersB["orders"] > 2]["visitorId"],
    ],
    axis=0,
)
usersWithExpensiveOrders = orders[orders["revenue"] > 30000]["visitorId"]
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[np.logical_not(ordersByUsersA["visitorId"].isin(abnormalUsers))][
            "orders"
        ],
        pd.Series(
            0,
            index=np.arange(
                data["visitorsPerDateA"].sum() - len(ordersByUsersA["orders"])
            ),
            name="orders",
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[np.logical_not(ordersByUsersB["visitorId"].isin(abnormalUsers))][
            "orders"
        ],
        pd.Series(
            0,
            index=np.arange(
                data["visitorsPerDateB"].sum() - len(ordersByUsersB["orders"])
            ),
            name="orders",
        ),
    ],
    axis=0,
)
print("{0:.5f}".format(st.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print("{0:.3f}".format(sampleBFiltered.mean() / sampleAFiltered.mean() - 1))
# Out:
# 0.01334
# 0.172

# %% [markdown]
# Вывод: Как и в случае с сырыми данными, статистическая значимость достигнута. Сегмент B значительно лучше сегмента A.
#
# P-value меньше 0.05, потому нулевую гипотезу отвергаем. Различие в среднем количестве заказов между группами достигло 17,2%.
# Осталось сравнить средние чеки по «очищенным данным».
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>
#
# ### Расчёт статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным.

# %%
print(
    "{0:.3f}".format(
        st.mannwhitneyu(
            orders[
                np.logical_and(
                    orders["group"] == "A",
                    np.logical_not(orders["visitorId"].isin(abnormalUsers)),
                )
            ]["revenue"],
            orders[
                np.logical_and(
                    orders["group"] == "B",
                    np.logical_not(orders["visitorId"].isin(abnormalUsers)),
                )
            ]["revenue"],
        )[1]
    )
)

print(
    "{0:.3f}".format(
        orders[
            np.logical_and(
                orders["group"] == "B",
                np.logical_not(orders["visitorId"].isin(abnormalUsers)),
            )
        ]["revenue"].mean()
        / orders[
            np.logical_and(
                orders["group"] == "A",
                np.logical_not(orders["visitorId"].isin(abnormalUsers)),
            )
        ]["revenue"].mean()
        - 1
    )
)
# Out:
# 0.720
# -0.023

# %% [markdown]
# P-value по-прежнему больше 0.05, хотя и немного ниже. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет даже после удаления аномально крупных покупок.
# Кроме того, после удаления аномально крупных покупок средний чек группы B стал даже ниже среднего чека группы A, но всего на 2,3% .
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>
#
# ### Принятие решения по результатам теста и его объяснение. Варианты решений:
#  - Остановить тест, зафиксировать победу одной из групп.
#  - Остановить тест, зафиксировать отсутствие различий между группами.
#  - Продолжить тест.

# %% [markdown]
# Из полученных тестов зафиксирую следующее:
#
# - Есть статистически значимое различие по конверсии между группами как по сырым данным, так и после фильтрации аномалий.
# - При этом нет статистически значимого различия по среднему чеку между группами как по сырым данным, так и после фильтрации аномалий.
# - График различия конверсии между группами сообщает, что результаты группы B лучше группы A: имеют тенденцию к росту, либо зафиксировались около среднего значения.

# %%
plt.plot(
    mergedCumulativeConversions["date"],
    mergedCumulativeConversions["conversionB"]
    / mergedCumulativeConversions["conversionA"]
    - 1,
    label="Относительный прирост кумулятивного среднего количества заказов на посетителя группы B относительно группы A",
)
plt.legend()

plt.axhline(y=0, color="black", linestyle="--")
plt.axhline(y=0.2, color="grey", linestyle="--")
plt.axis([dt.datetime(2019, 8, 1), dt.datetime(2019, 9, 1), -0.2, 0.3])

plt.show()

# %% [markdown]
# График различия среднего чека колеблется: он-то и позволил вам найти аномалии. Сделать из этого графика определённые выводы нельзя.

# %%
# график отношения кумулятивного среднего чека групп А и В
display_merged_Cumulative_Revenue(cumulativeRevenueA, cumulativeRevenueB)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Исходя из фактов выше, можно остановить тест и признать группу `B` более успешной с точки зрения конверсии при примерно одинаковых размерах среднего чека обеих групп и существенном влиянии отдельных покупок на этот показатель.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Итоги первой итерации :</b> Молодец, получилась хорошая работа, нужно исправить в некоторых местах по моим комментариям. Жду на повторную проверку!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Хорошая работа, молодец! Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# **Дополнительные материалы:**
#
# [Вебинары под эгидой Практикума](https://vk.com/yandex.praktikum?w=wall-176471180_2144),
#
# [Лекции Анатолия Карпова 1](https://www.youtube.com/watch?v=jnFVmtaeSA0&list=WL&index=19&t=2s) [2](https://www.youtube.com/watch?v=gljfGAkgX_o&list=WL&index=4)
#
# Материалы [gopractice](https://gopractice.ru/summary/)
#
# Лекцию Карта статистических методов [Смотреть видео](https://www.youtube.com/watch?v=-zps6hm0nX8&t=1269s)
# </div>
